# %%
# Import Modules

from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import rasterio as rio
# from rasterio.plot import plotting_extent
# from rasterio.plot import show
# from rasterio.plot import reshape_as_raster, reshape_as_image

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go

np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
import spectral.io.envi as envi
from find_path_nextcloud import find_path_nextcloud


path_nextcloud = find_path_nextcloud()
path_folder = path_nextcloud + 'Daten_Gyrocopter/Oldenburg/DigitalesOberflaechenModel_normiert/'
file_name = 'DGM-DTM-Resized.hdr'

path_file = path_folder + file_name

# %%
# Read Header-Info (.hdr)
file_hdr = envi.open(path_file)
file_hdr
# Out:
# 	Data Source:   'C:/Users/fgrassxx/Nextcloud/Master_Data_Science/2_Semester/Projekt_Data_Science_1_SS22/Daten_Gyrocopter/Oldenburg/DigitalesOberflaechenModel_normiert/DGM-DTM-Resized'
# 	# Rows:           1980
# 	# Samples:        3500
# 	# Bands:             1
# 	Interleave:        BSQ
# 	Quantization:  32 bits
# 	Data format:   float32

# %%
print('Metadaten')
file_meta = file_hdr.metadata

file_meta['map info']
# Out:
# Metadaten
# ['UTM',
#  '1.000',
#  '1.000',
#  '445703.000',
#  '5888996.500',
#  '5.0000000000e-001',
#  '5.0000000000e-001',
#  '32',
#  'North',
#  'WGS-84',
#  'units=Meters']

# %%
path_nextcloud = find_path_nextcloud()
path_folder = path_nextcloud + 'Daten_Gyrocopter/Oldenburg/DigitalesOberflaechenModel_normiert/'


path_hdr = path_folder + 'DGM-DTM-Resized.hdr'
path_dat =  path_folder + 'DGM-DTM-Resized'

img = envi.open(file=path_hdr, image=path_dat)

# %%
img
# Out:
# 	Data Source:   'C:/Users/fgrassxx/Nextcloud/Master_Data_Science/2_Semester/Projekt_Data_Science_1_SS22/Daten_Gyrocopter/Oldenburg/DigitalesOberflaechenModel_normiert/DGM-DTM-Resized'
# 	# Rows:           1980
# 	# Samples:        3500
# 	# Bands:             1
# 	Interleave:        BSQ
# 	Quantization:  32 bits
# 	Data format:   float32

# %%
from spectral import *

# %%
img = open_image(file=path_hdr)

# %%
img.__class__
# Out:
# spectral.io.bsqfile.BsqFile

# %%
img.shape
# Out:
# (1980, 3500, 1)

# %%
print(img)
# Out:
# 	Data Source:   'C:/Users/fgrassxx/Nextcloud/Master_Data_Science/2_Semester/Projekt_Data_Science_1_SS22/Daten_Gyrocopter/Oldenburg/DigitalesOberflaechenModel_normiert/DGM-DTM-Resized'
# 	# Rows:           1980
# 	# Samples:        3500
# 	# Bands:             1
# 	Interleave:        BSQ
# 	Quantization:  32 bits
# 	Data format:   float32

# %%
pixel = img[500:1000,500:1000]

pixel.shape
# Out:
# (500, 500, 1)

# %%
arr = img.load()
arr.__class__
# Out:
# spectral.image.ImageArray

# %%
print(arr.info())
# Out:
# 	# Rows:           1980
# 	# Samples:        3500
# 	# Bands:             1
# 	Data format:   float32

# %%
arr.shape
# Out:
# (1980, 3500, 1)

# %%
view = imshow(pixel, figsize=(30,50))

# %%
view = imshow(arr, figsize=(30,50))

# %%
save_rgb(filename = 'Ausschnitt_Oldenburg_DOM.jpg', data = pixel)

# %%
save_rgb(filename = 'Oldenburg_DOM.jpg', data = arr)
