# %%
# Import Modules

from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import rasterio as rio
# from rasterio.plot import plotting_extent
# from rasterio.plot import show
# from rasterio.plot import reshape_as_raster, reshape_as_image

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go

np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %%
from find_path_nextcloud import find_path_nextcloud
path_nextcloud = find_path_nextcloud()

# %%
path_file = path_nextcloud + 'Daten_Gyrocopter/Oldenburg/Hyperspektral/Oldenburg-all.tif'

# %%
# l = []
# with rio.open(path_file, 'r') as f:
#     for band in range(1,101):
#         l.append(f.read(band))

l = []
with rio.open(path_file, 'r') as f:
    l.append(f.read())

# %%
arr_st = np.stack(l)
arr_st = arr_st[0]

# %%
print(f'Height: {arr_st.shape[1]}\nWidth: {arr_st.shape[2]}\nBands: {arr_st.shape[0]}')
# Out:
# Height: 1980
# Width: 3500
# Bands: 107

# %%
ep.plot_bands(arr_st, cmap = 'gist_earth', figsize = (20, 30), cols = 2, cbar = True)
plt.show()

# %%
rgb = ep.plot_rgb(arr_st,
                  rgb=(60,50,30),
                  figsize=(20, 30),
                  # title='RGB Composite Image'
                  )

plt.show()
